# %%
import pandas as pd

# %%
df=pd.read_csv("HRdataset.csv")

# %%
df.head()
# Out:
#               Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0       Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 1  Ait Sidi, Karthikeyan     10084.0        1.0              1.0    Male
# 2         Akinkuolie, Sarah  10196.0        1.0              1.0    Male
# 3              Alagbe,Trina  10088.0        1.0              1.0  Female
# 4          Anderson, Carol   10069.0        0.0              2.0    Male
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# 0          1.0     5.0          4.0                     0.0   62506.0  ...
# 1          5.0     3.0          3.0                     0.0  104437.0  ...
# 2          5.0     5.0          3.0                     0.0   64955.0  ...
# 3          1.0     5.0          3.0                     0.0   64991.0  ...
# 4          5.0     5.0          3.0                     0.0   50825.0  ...
#
#    PerformanceRating  StandardHours StockOptionLevel TotalWorkingYears  \
# ...

# %%
df.loc[df["Position"]== "Production Technician I"].count()
# Out:
# Employee_Name                 137
# EmpID                         137
# MarriedID                     137
# MaritalStatusID               137
# Gender                        137
# EmpStatusID                   137
# DeptID                        137
# PerfScoreID                   137
# FromDiversityJobFairID        137
# Salary                        137
# Termd                         137
# PositionID                    137
# Position                      137
# State                         137
# Zip                           137
# DOB                           137
# Sex                           137
# MaritalDesc                   137
# CitizenDesc                   137
# DateofHire                    137
# DateofTermination              52
# TermReason                    137
# EmploymentStatus              137
# Department                    137
# ManagerName                   137
# ManagerID                     133
# RecruitmentSource             137
# ...

# %%
df.loc[df["Gender"]=="Male"].count()
# Out:
# Employee_Name                 193
# EmpID                         193
# MarriedID                     193
# MaritalStatusID               193
# Gender                        194
# EmpStatusID                   193
# DeptID                        193
# PerfScoreID                   193
# FromDiversityJobFairID        193
# Salary                        193
# Termd                         193
# PositionID                    193
# Position                      193
# State                         193
# Zip                           193
# DOB                           193
# Sex                           193
# MaritalDesc                   193
# CitizenDesc                   193
# DateofHire                    193
# DateofTermination              64
# TermReason                    193
# EmploymentStatus              193
# Department                    193
# ManagerName                   193
# ManagerID                     187
# RecruitmentSource             193
# ...

# %%
df.loc[df["ManagerName"]=="Michael Albert"].count()
# Out:
# Employee_Name                 22
# EmpID                         22
# MarriedID                     22
# MaritalStatusID               22
# Gender                        22
# EmpStatusID                   22
# DeptID                        22
# PerfScoreID                   22
# FromDiversityJobFairID        22
# Salary                        22
# Termd                         22
# PositionID                    22
# Position                      22
# State                         22
# Zip                           22
# DOB                           22
# Sex                           22
# MaritalDesc                   22
# CitizenDesc                   22
# DateofHire                    22
# DateofTermination              9
# TermReason                    22
# EmploymentStatus              22
# Department                    22
# ManagerName                   22
# ManagerID                     22
# RecruitmentSource             22
# PerformanceScore              22
# ...

# %%
df.loc[df["EmploymentStatus"]=="Active"].count()
# Out:
# Employee_Name                 207
# EmpID                         207
# MarriedID                     207
# MaritalStatusID               207
# Gender                        207
# EmpStatusID                   207
# DeptID                        207
# PerfScoreID                   207
# FromDiversityJobFairID        207
# Salary                        207
# Termd                         207
# PositionID                    207
# Position                      207
# State                         207
# Zip                           207
# DOB                           207
# Sex                           207
# MaritalDesc                   207
# CitizenDesc                   207
# DateofHire                    207
# DateofTermination               0
# TermReason                    207
# EmploymentStatus              207
# Department                    207
# ManagerName                   207
# ManagerID                     199
# RecruitmentSource             207
# ...

# %%
df.loc[(df["EmploymentStatus"]=="Active") & (df["MaritalDesc"]=="Married")]
# Out:
#          Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 3         Alagbe,Trina  10088.0        1.0              1.0  Female
# 16    Beak, Kimberly    10023.0        1.0              1.0    Male
# 22       Billis, Helen  10003.0        1.0              1.0  Female
# 26   Boutwell, Bonalyn  10081.0        1.0              1.0  Female
# 29          Brown, Mia  10238.0        1.0              1.0  Female
# ..                 ...      ...        ...              ...     ...
# 271   Sullivan, Kissy   10158.0        1.0              1.0    Male
# 272  Sullivan, Timothy  10117.0        1.0              1.0    Male
# 275       Tannen, Biff  10173.0        1.0              1.0  Female
# 287      Turpin, Jumil  10045.0        1.0              1.0    Male
# 288    Valentin,Jackie  10205.0        1.0              1.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# ...

# %%
df.loc[(df["EmploymentStatus"]=="Voluntarily Terminated") & (df["MaritalDesc"]=="Divorced")]
# Out:
#           Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 4      Anderson, Carol   10069.0        0.0              2.0    Male
# 14        Barton, Nader  10066.0        0.0              2.0    Male
# 103       Gerke, Melisa  10122.0        0.0              2.0  Female
# 119        Gross, Paula  10059.0        0.0              2.0    Male
# 136         Huynh, Ming  10160.0        0.0              2.0    Male
# 158   Langford, Lindsey  10106.0        0.0              2.0    Male
# 224      Power, Morissa  10187.0        0.0              2.0    Male
# 226    Purinton, Janine  10262.0        0.0              2.0    Male
# 229      Rarrick, Quinn  10152.0        0.0              2.0    Male
# 231      Rhoads, Thomas  10058.0        0.0              2.0    Male
# 233       Roberson, May  10230.0        0.0              2.0  Female
# 244       Ruiz, Ricardo  10222.0        0.0              2.0    Male
# 249       Salter, Jason  10229.0        0.0              2.0    Male
# ...

# %%
for x in df.index:
    if df.loc[x,"Position"]=="Production Technician II":
        if df.loc[x,"EngagementSurvey"] == df["EngagementSurvey"].max():
            print(df.loc[x,"Employee_Name"])
# Out:
# Hankard, Earnest
# Hendrickson, Trina
# Manchester, Robyn
# Mancuso, Karen
# Carthy, B'rigit
# Oliver, Brooke
# Winthrop, Jordan

# %%
for x in df.index:
    if df.loc[x,"EmploymentStatus"]=="Active":
        if df.loc[x,"Salary"]<60000:
            print(df.loc[x,"Employee_Name"])
# Out:
# Anderson, Linda
# Athwal, Sam
# Bachiochi, Linda
# Bacong, Alejandro
# Barone, Francesco  A
# Beatrice, Courtney
# Becker, Scott
# Bernstein, Sean
# Carey, Michael
# Chan, Lin
# Clukey, Elijian
# Crimmings,   Jean
# Darson, Jene'ya
# Davis, Daniel
# Dee, Randy
# Desimone, Carl
# Dickinson, Geoff
# Dietrich, Jenna
# Dobrin, Denisa  S
# Engdahl, Jean
# England, Rex
# Erilus, Angela
# Fett, Boba
# Fidelia,  Libby
# Garcia, Raul
# Gaul, Barbara
# Gentry, Mildred
# Girifalco, Evelyn
# Gold, Shenice
# Gonzalez, Cayo
# Gordon, David
# Goyal, Roxana
# Handschiegl, Joanne
# Heitzman, Anthony
# Hudson, Jane
# Ivey, Rose
# Jacobi, Hannah
# Keatts, Kramer
# Knapp, Bradley  J
# Langton, Enrico
# Lindsay, Leonara
# Lydon, Allison
# Mahoney, Lauren
# Maurice, Shana
# Carthy, B'rigit
# Medeiros, Jennifer
# Monkfish, Erasumus
# Morway, Tanya
# Myers, Michael
# Newman, Richard
# Ngodup, Shari
# Osturnka, Adeel
# Owad, Clinton
# Pitt, Brad
# Punjabhi, Louis
# Rivera, Haley
# Saar-Beckles, Melinda
# ...

# %%
for x in df.index:
    if df.loc[x,"Salary"]==df["Salary"].max():
        print(df.loc[x,"Position"])
# Out:
# President & CEO

# %%
for x in df.index:
    if df.loc[x,"Salary"] < df["Salary"].mean():
        print(df.loc[x,"Employee_Name"])
# Out:
# Adinolfi, Wilson  K
# Akinkuolie, Sarah
# Alagbe,Trina
# Anderson, Carol
# Anderson, Linda
# Athwal, Sam
# Bachiochi, Linda
# Bacong, Alejandro
# Baczenski, Rachael
# Barbara, Thomas
# Barone, Francesco  A
# Barton, Nader
# Bates, Norman
# Beatrice, Courtney
# Becker, Scott
# Bernstein, Sean
# Biden, Lowan  M
# Billis, Helen
# Blount, Dianna
# Bondwell, Betsy
# Brill, Donna
# Brown, Mia
# Buccheri, Joseph
# Bugali, Josephine
# Burke, Joelle
# Burkett, Benjamin
# Carey, Michael
# Chace, Beatrice
# Chan, Lin
# Chang, Donovan  E
# Chigurh, Anton
# Chivukula, Enola
# Cierpiszewski, Caroline
# Clayton, Rick
# Cloninger, Jennifer
# Close, Phil
# Clukey, Elijian
# Cockel, James
# Cole, Spencer
# Corleone, Michael
# Cornett, Lisa
# Crimmings,   Jean
# Daneault, Lynn
# Darson, Jene'ya
# Davis, Daniel
# Dee, Randy
# DeGweck,  James
# Delarge, Alex
# Demita, Carla
# Desimone, Carl
# Dickinson, Geoff
# Dietrich, Jenna
# DiNocco, Lily
# Dobrin, Denisa  S
# Dunne, Amy
# Eaton, Marianne
# ...

# %%
for x in df.index:
    if df.loc[x,"Salary"] < df["Salary"].mean():
        if df.loc[x,"EmpSatisfaction"]<3:
            print(df.loc[x,"Employee_Name"])
# Out:
# Brown, Mia
# Corleone, Michael
# Desimone, Carl
# Dietrich, Jenna
# Erilus, Angela
# Miller, Ned
# O'hare, Lynn
# Sparks, Taylor
# Stansfield, Norman
# Ybarra, Catherine

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["EmpSatisfaction"],df["DistanceFromHome"])

# %%
for x in df.index:
    if df.loc[x,"StockOptionLevel"] < 0:
        print(df.loc[x,"Employee_Name"])

# %%
plt.scatter(df["MonthlyIncome"], df["JobSatisfaction"])

# %%
df.loc[df["StockOptionLevel"] > 0].count()
# Out:
# Employee_Name                 171
# EmpID                         171
# MarriedID                     171
# MaritalStatusID               171
# Gender                        172
# EmpStatusID                   171
# DeptID                        171
# PerfScoreID                   171
# FromDiversityJobFairID        171
# Salary                        171
# Termd                         171
# PositionID                    171
# Position                      171
# State                         171
# Zip                           171
# DOB                           171
# Sex                           171
# MaritalDesc                   171
# CitizenDesc                   171
# DateofHire                    171
# DateofTermination              59
# TermReason                    171
# EmploymentStatus              171
# Department                    171
# ManagerName                   171
# ManagerID                     169
# RecruitmentSource             171
# ...

# %%
df.loc[df["PerformanceRating"]>3]
# Out:
#                  Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 1     Ait Sidi, Karthikeyan     10084.0        1.0              1.0    Male
# 6              Andreola, Colby  10194.0        0.0              0.0  Female
# 7                  Athwal, Sam  10062.0        0.0              4.0    Male
# 8             Bachiochi, Linda  10114.0        0.0              0.0    Male
# 21             Biden, Lowan  M  10226.0        0.0              2.0    Male
# 26           Boutwell, Bonalyn  10081.0        1.0              1.0  Female
# 44           Chang, Donovan  E  10154.0        0.0              0.0  Female
# 46            Chivukula, Enola  10240.0        0.0              0.0    Male
# 47   Cierpiszewski, Caroline    10168.0        0.0              0.0    Male
# 48               Clayton, Rick  10220.0        0.0              0.0    Male
# 52               Cockel, James  10261.0        0.0              0.0  Female
# ...

# %%
df.loc[df["EmpStatusID"]==5].count()
# Out:
# Employee_Name                 88
# EmpID                         88
# MarriedID                     88
# MaritalStatusID               88
# Gender                        88
# EmpStatusID                   88
# DeptID                        88
# PerfScoreID                   88
# FromDiversityJobFairID        88
# Salary                        88
# Termd                         88
# PositionID                    88
# Position                      88
# State                         88
# Zip                           88
# DOB                           88
# Sex                           88
# MaritalDesc                   88
# CitizenDesc                   88
# DateofHire                    88
# DateofTermination             88
# TermReason                    88
# EmploymentStatus              88
# Department                    88
# ManagerName                   88
# ManagerID                     88
# RecruitmentSource             88
# PerformanceScore              88
# ...

# %%
df.head()
# Out:
#               Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0       Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 1  Ait Sidi, Karthikeyan     10084.0        1.0              1.0    Male
# 2         Akinkuolie, Sarah  10196.0        1.0              1.0    Male
# 3              Alagbe,Trina  10088.0        1.0              1.0  Female
# 4          Anderson, Carol   10069.0        0.0              2.0    Male
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# 0          1.0     5.0          4.0                     0.0   62506.0  ...
# 1          5.0     3.0          3.0                     0.0  104437.0  ...
# 2          5.0     5.0          3.0                     0.0   64955.0  ...
# 3          1.0     5.0          3.0                     0.0   64991.0  ...
# 4          5.0     5.0          3.0                     0.0   50825.0  ...
#
#    PerformanceRating  StandardHours StockOptionLevel TotalWorkingYears  \
# ...

# %%
df.loc[df["Department"]=="IT/IS"].count()
# Out:
# Employee_Name                 50
# EmpID                         50
# MarriedID                     50
# MaritalStatusID               50
# Gender                        50
# EmpStatusID                   50
# DeptID                        50
# PerfScoreID                   50
# FromDiversityJobFairID        50
# Salary                        50
# Termd                         50
# PositionID                    50
# Position                      50
# State                         50
# Zip                           50
# DOB                           50
# Sex                           50
# MaritalDesc                   50
# CitizenDesc                   50
# DateofHire                    50
# DateofTermination             10
# TermReason                    50
# EmploymentStatus              50
# Department                    50
# ManagerName                   50
# ManagerID                     50
# RecruitmentSource             50
# PerformanceScore              50
# ...

# %%
df.loc[df["Department"]=="Software Engineering"].count()
# Out:
# Employee_Name                 11
# EmpID                         11
# MarriedID                     11
# MaritalStatusID               11
# Gender                        11
# EmpStatusID                   11
# DeptID                        11
# PerfScoreID                   11
# FromDiversityJobFairID        11
# Salary                        11
# Termd                         11
# PositionID                    11
# Position                      11
# State                         11
# Zip                           11
# DOB                           11
# Sex                           11
# MaritalDesc                   11
# CitizenDesc                   11
# DateofHire                    11
# DateofTermination              4
# TermReason                    11
# EmploymentStatus              11
# Department                    11
# ManagerName                   11
# ManagerID                     11
# RecruitmentSource             11
# PerformanceScore              11
# ...

# %%
df.loc[df["Department"]=="Production"].count()
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# Gender                        0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# PerformanceScore              0
# EngagementSurvey              0
# ...

# %%
df.head()
# Out:
#               Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0       Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 1  Ait Sidi, Karthikeyan     10084.0        1.0              1.0    Male
# 2         Akinkuolie, Sarah  10196.0        1.0              1.0    Male
# 3              Alagbe,Trina  10088.0        1.0              1.0  Female
# 4          Anderson, Carol   10069.0        0.0              2.0    Male
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# 0          1.0     5.0          4.0                     0.0   62506.0  ...
# 1          5.0     3.0          3.0                     0.0  104437.0  ...
# 2          5.0     5.0          3.0                     0.0   64955.0  ...
# 3          1.0     5.0          3.0                     0.0   64991.0  ...
# 4          5.0     5.0          3.0                     0.0   50825.0  ...
#
#    PerformanceRating  StandardHours StockOptionLevel TotalWorkingYears  \
# ...

# %%
for x in df.index:
        if df.loc[x,"RecruitmentSource"] == "Diversity Job Fair":
            print(df.loc[x,"EmpID"])
# Out:
# 10114.0
# 10252.0
# 10242.0
# 10012.0
# 10081.0
# 10238.0
# 10203.0
# 10122.0
# 10283.0
# 10031.0
# 10300.0
# 10165.0
# 10008.0
# 10004.0
# 10128.0
# 10288.0
# 10223.0
# 10215.0
# 10037.0
# 10005.0
# 10131.0
# 10222.0
# 10295.0
# 10291.0
# 10153.0
# 10221.0
# 10102.0
# 10274.0
# 10264.0

# %%
for x in df.index:
    if (df.loc[x,"Salary"] == df["Salary"].max()) & (df.loc[x,"RecruitmentSource"] == "Diversity Job Fair"):
        print(df.loc[x,"EmpID"])

# %%
df.loc[df["EmploymentStatus"]=="Terminated for Cause"].count()
# Out:
# Employee_Name                 16
# EmpID                         16
# MarriedID                     16
# MaritalStatusID               16
# Gender                        16
# EmpStatusID                   16
# DeptID                        16
# PerfScoreID                   16
# FromDiversityJobFairID        16
# Salary                        16
# Termd                         16
# PositionID                    16
# Position                      16
# State                         16
# Zip                           16
# DOB                           16
# Sex                           16
# MaritalDesc                   16
# CitizenDesc                   16
# DateofHire                    16
# DateofTermination             16
# TermReason                    16
# EmploymentStatus              16
# Department                    16
# ManagerName                   16
# ManagerID                     16
# RecruitmentSource             16
# PerformanceScore              16
# ...

# %%
c=df["Position"].unique()

# %%
c
# Out:
# array(['Production Technician I', 'Sr. DBA', 'Production Technician II',
#        'Software Engineer', 'IT Support', 'Data Analyst',
#        'Database Administrator', 'Enterprise Architect', 'Sr. Accountant',
#        'Production Manager', 'Accountant I', 'Area Sales Manager',
#        'Software Engineering Manager', 'BI Director',
#        'Director of Operations', 'Sr. Network Engineer', 'Sales Manager',
#        'BI Developer', 'IT Manager - Support', 'Network Engineer',
#        'IT Director', 'Director of Sales', 'Administrative Assistant',
#        'President & CEO', 'Senior BI Developer',
#        'Shared Services Manager', 'IT Manager - Infra',
#        'Principal Data Architect', 'Data Architect', 'IT Manager - DB',
#        'Data Analyst ', 'CIO', nan], dtype=object)

# %%
k=0
for k in df.index:
    if df.loc[k,c]:
        print(df.loc[k,"Employee_Name"])
        k=k+1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-361077e94afb> in <module>
#       1 k=0
#       2 for k in df.index:
# ----> 3     if df.loc[k,c]:
#       4         print(df.loc[k,"Employee_Name"])
#       5         k=k+1
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
# ...
