# %%
import pandas as pd

# %%
d=pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
d
# Out:
#        InvoiceID Branch       City Customertype  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw       Normal  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# 2        Home and lifestyle      46.33         7  16.2155   340.5255
# ...

# %%
d.head()
# Out:
#      InvoiceID Branch       City Customertype  Gender             Productline  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw       Normal  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
#
#    Unitprice  Quantity      Tax     Total       Date   Time      Payment  \
# 0      74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1      15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2      46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3      58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4      86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#      cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
X=0
x=0
for X in d.index:
    y=d.loc[X,"Unitprice"]
    X=X+0
    x=x+1
d.max()
# Out:
# InvoiceID                        898-04-2717
# Branch                                     C
# City                                  Yangon
# Customertype                          Normal
# Gender                                  Male
# Productline                Sports and travel
# Unitprice                              99.96
# Quantity                                  10
# Tax                                    49.65
# Total                                1042.65
# Date                                3/9/2019
# Time                                   20:59
# Payment                              Ewallet
# cogs                                   993.0
# gross_margin_percentage             4.761905
# gross_iincome                          49.65
# Rating                                  10.0
# dtype: object

# %%
d.min()
# Out:
# InvoiceID                             101-17-6199
# Branch                                          A
# City                                     Mandalay
# Customertype                               Member
# Gender                                     Female
# Productline                Electronic accessories
# Unitprice                                   10.08
# Quantity                                        1
# Tax                                        0.5085
# Total                                     10.6785
# Date                                     1/1/2019
# Time                                        10:00
# Payment                                      Cash
# cogs                                        10.17
# gross_margin_percentage                  4.761905
# gross_iincome                              0.5085
# Rating                                        4.0
# dtype: object

# %%
d.mean()
# Out:
# Unitprice                   55.672130
# Quantity                     5.510000
# Tax                         15.379369
# Total                      322.966749
# cogs                       307.587380
# gross_margin_percentage      4.761905
# gross_iincome               15.379369
# Rating                       6.972700
# dtype: float64

# %%
d.loc[0,"City"]
# Out:
# 'Yangon'

# %%
d.loc[1,"Unitprice"]
# Out:
# 15.28

# %%
new_data=[len(d)]
for x in d.index:
    new_data.append(d.loc[x,"Tax"])

# %%
new_data
# Out:
# [1000,
#  26.1415,
#  3.82,
#  16.2155,
#  23.288,
#  30.2085,
#  29.8865,
#  20.652,
#  36.78,
#  3.626,
#  8.226,
#  2.896,
#  5.102,
#  11.7375,
#  21.595,
#  35.69,
#  28.116,
#  24.1255,
#  21.783,
#  8.2005,
#  4.03,
#  21.51,
#  13.197,
#  3.32,
#  8.64,
#  13.2945,
#  21.036,
#  1.676,
#  8.767,
#  22.09,
#  11.2005,
#  23.5325,
#  35.1315,
#  33.512,
#  9.658,
#  19.884,
#  3.406,
#  15.655,
#  27.396,
#  21.968,
#  12.048,
#  4.336,
#  5.611,
#  20.736,
#  39.48,
#  1.537,
#  18.792,
#  25.5105,
#  9.0045,
#  5.679,
#  41.315,
#  31.99,
#  11.1475,
#  3.574,
#  0.7715,
#  1.616,
#  34.392,
#  4.434,
#  35.84,
#  36.175,
#  9.183,
#  3.711,
#  16.719,
#  24.7815,
#  7.905,
#  15.148,
#  7.935,
#  3.347,
#  29.283,
#  39.385,
#  0.9165,
#  44.74,
#  31.06,
#  7.278,
#  22.773,
#  33.6015,
#  20.825,
#  22.068,
#  9.0045,
#  39.155,
#  5.095,
#  29.757,
#  14.502,
#  7.7,
#  16.072,
#  12.2275,
#  29.071,
#  19.13,
#  17.283,
#  2.1235,
#  23.097,
#  9.476,
#  22.43,
# ...

# %%
new_data=[len(d)]
for x in d.index:
    if(d.loc[x,"Branch"]=="A"):
        new_data.append(d.loc[x,"InvoiceID"])
new_data
# Out:
# [1000,
#  '750-67-8428',
#  '631-41-3108',
#  '123-19-1176',
#  '373-73-7910',
#  '355-53-5943',
#  '665-32-9167',
#  '365-64-0515',
#  '252-56-2699',
#  '829-34-3910',
#  '656-95-9349',
#  '765-26-6951',
#  '329-62-1586',
#  '636-48-8204',
#  '549-59-1358',
#  '227-03-5010',
#  '189-17-4241',
#  '848-62-7243',
#  '595-11-5460',
#  '129-29-8530',
#  '272-65-1806',
#  '162-48-8011',
#  '106-35-6779',
#  '635-40-6220',
#  '817-48-8732',
#  '199-75-8169',
#  '877-22-3308',
#  '232-11-3025',
#  '382-03-4532',
#  '287-21-9091',
#  '381-20-0914',
#  '633-44-8566',
#  '504-35-8843',
#  '873-51-0671',
#  '594-34-4444',
#  '865-92-6136',
#  '212-62-1842',
#  '704-48-3927',
#  '630-74-5166',
#  '645-44-1170',
#  '642-32-2990',
#  '638-60-7125',
#  '668-90-8900',
#  '870-54-3162',
#  '802-70-5316',
#  '700-81-1757',
#  '354-39-5160',
#  '575-30-8091',
#  '239-10-7476',
#  '685-64-1609',
#  '238-49-0436',
#  '746-94-0204',
#  '782-95-9291',
#  '275-28-0149',
#  '101-17-6199',
#  '687-47-8271',
# ...

# %%
mew_data=[len(d)]
for x in d.index:
    mew_data.append(d.loc[x,"Unitprice"])
mew_data
# Out:
# [1000,
#  74.69,
#  15.28,
#  46.33,
#  58.22,
#  86.31,
#  85.39,
#  68.84,
#  73.56,
#  36.26,
#  54.84,
#  14.48,
#  25.51,
#  46.95,
#  43.19,
#  71.38,
#  93.72,
#  68.93,
#  72.61,
#  54.67,
#  40.3,
#  86.04,
#  87.98,
#  33.2,
#  34.56,
#  88.63,
#  52.59,
#  33.52,
#  87.67,
#  88.36,
#  24.89,
#  94.13,
#  78.07,
#  83.78,
#  96.58,
#  99.42,
#  68.12,
#  62.62,
#  60.88,
#  54.92,
#  30.12,
#  86.72,
#  56.11,
#  69.12,
#  98.7,
#  15.37,
#  93.96,
#  56.69,
#  20.01,
#  18.93,
#  82.63,
#  91.4,
#  44.59,
#  17.87,
#  15.43,
#  16.16,
#  85.98,
#  44.34,
#  89.6,
#  72.35,
#  30.61,
#  24.74,
#  55.73,
#  55.07,
#  15.81,
#  75.74,
#  15.87,
#  33.47,
#  97.61,
#  78.77,
#  18.33,
#  89.48,
#  62.12,
#  48.52,
#  75.91,
#  74.67,
#  41.65,
#  49.04,
#  20.01,
#  78.31,
#  20.38,
#  99.19,
#  96.68,
#  19.25,
#  80.36,
#  48.91,
#  83.06,
#  76.52,
#  49.38,
#  42.47,
#  76.99,
#  47.38,
#  44.86,
#  21.98,
#  64.36,
#  89.75,
#  97.16,
#  87.87,
#  12.45,
#  52.75,
# ...

# %%
max(mew_data)
# Out:
# 1000

# %%
min(mew_data)
# Out:
# 10.08

# %%
sum(mew_data)/len(mew_data)
# Out:
# 56.61551448551446

# %%
qew_data=[]
for x in d.index:
    qew_data.append(d.loc[x,"Quantity"])
qew_data
# Out:
# [7,
#  5,
#  7,
#  8,
#  7,
#  7,
#  6,
#  10,
#  2,
#  3,
#  4,
#  4,
#  5,
#  10,
#  10,
#  6,
#  7,
#  6,
#  3,
#  2,
#  5,
#  3,
#  2,
#  5,
#  3,
#  8,
#  1,
#  2,
#  5,
#  9,
#  5,
#  9,
#  8,
#  2,
#  4,
#  1,
#  5,
#  9,
#  8,
#  8,
#  1,
#  2,
#  6,
#  8,
#  2,
#  4,
#  9,
#  9,
#  6,
#  10,
#  7,
#  5,
#  4,
#  1,
#  2,
#  8,
#  2,
#  8,
#  10,
#  6,
#  3,
#  6,
#  9,
#  10,
#  4,
#  10,
#  2,
#  6,
#  10,
#  1,
#  10,
#  10,
#  3,
#  6,
#  9,
#  10,
#  9,
#  9,
#  10,
#  5,
#  6,
#  3,
#  8,
#  4,
#  5,
#  7,
#  5,
#  7,
#  1,
#  6,
#  4,
#  10,
#  7,
#  9,
#  1,
#  1,
#  10,
#  6,
#  3,
#  6,
#  1,
#  9,
#  9,
#  6,
#  7,
#  10,
#  6,
#  6,
#  9,
#  10,
#  2,
#  3,
#  7,
#  9,
#  9,
#  3,
#  5,
#  1,
#  10,
#  2,
#  8,
#  7,
#  9,
#  8,
#  8,
#  7,
#  5,
#  9,
#  8,
#  9,
#  7,
#  6,
#  4,
#  6,
#  6,
#  3,
#  5,
#  6,
#  10,
#  8,
#  10,
#  10,
#  10,
#  1,
#  6,
#  6,
#  10,
#  4,
#  8,
#  8,
#  4,
#  7,
#  9,
#  6,
#  8,
#  5,
#  1,
#  5,
#  9,
#  6,
#  8,
#  1,
#  7,
# ...

# %%
min(qew_data)
# Out:
# 1

# %%
max(qew_data)
# Out:
# 10

# %%
sum(qew_data)/len(qew_data)
# Out:
# 5.51

# %%
d.head()
# Out:
#      InvoiceID Branch       City Customertype  Gender             Productline  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw       Normal  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
#
#    Unitprice  Quantity      Tax     Total       Date   Time      Payment  \
# 0      74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1      15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2      46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3      58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4      86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#      cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
d=pd.read_csv("supermarket_sales - Sheet1.csv")
rew_data=[len(d.index)]
for x in d.index:
    if (d.loc[x,"Productline"]=="Health and Beauty"):
        rew_data.append(d.loc[x,"Quantity"])
max(rew_data)
# Out:
# 1000

# %%
min(rew_data)
# Out:
# 1000
