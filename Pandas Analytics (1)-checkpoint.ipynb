# %%
import pandas as pd

# %%
d=pd.read_csv("Supermarket.csv")

# %%
d
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
d.Unitprice
# Out:
# 0      74.69
# 1      15.28
# 2      46.33
# 3      58.22
# 4      86.31
#        ...
# 995    40.35
# 996    97.38
# 997    31.84
# 998    65.82
# 999    88.34
# Name: Unitprice, Length: 1000, dtype: float64

# %%
for x in d.index:
    print(d.Branch[x])
# Out:
# A
# C
# A
# A
# A
# C
# A
# C
# A
# B
# B
# B
# A
# A
# A
# B
# A
# A
# A
# B
# C
# B
# B
# A
# A
# A
# B
# A
# B
# A
# B
# B
# B
# A
# C
# C
# A
# A
# C
# B
# B
# C
# B
# C
# C
# B
# B
# B
# B
# C
# C
# A
# B
# C
# B
# C
# A
# A
# A
# C
# C
# C
# B
# A
# B
# A
# C
# B
# A
# A
# C
# C
# B
# C
# A
# C
# C
# A
# C
# C
# C
# B
# C
# C
# C
# C
# C
# A
# A
# B
# C
# C
# A
# B
# C
# A
# B
# C
# A
# B
# C
# C
# C
# A
# B
# A
# C
# A
# C
# C
# B
# C
# B
# A
# C
# C
# B
# B
# A
# B
# A
# C
# B
# C
# B
# A
# A
# C
# C
# B
# B
# A
# B
# B
# C
# C
# A
# A
# B
# A
# C
# C
# C
# C
# A
# C
# A
# C
# B
# A
# B
# C
# A
# C
# C
# A
# B
# B
# B
# B
# C
# A
# A
# C
# B
# B
# C
# A
# A
# A
# A
# B
# C
# B
# B
# A
# A
# C
# A
# C
# C
# C
# A
# C
# A
# B
# B
# B
# A
# C
# B
# B
# C
# B
# A
# C
# C
# A
# C
# C
# C
# B
# C
# B
# B
# A
# C
# C
# B
# B
# A
# C
# B
# B
# B
# A
# B
# A
# B
# B
# B
# B
# C
# C
# A
# C
# B
# C
# B
# A
# B
# B
# B
# B
# A
# A
# C
# C
# B
# A
# A
# A
# C
# A
# B
# A
# B
# A
# A
# B
# ...

# %%
d.head()
# Out:
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
# 4   5  373-73-7910      A     Yangon       Normal    Male
#
#               Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0       Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories      15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle      46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel      86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
for x in d.index:
    if d.City[x]=="Yangon":
        print(d.Branch[x])
# Out:
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# ...

# %%
d.Unitprice.max()
# Out:
# 99.96

# %%
d.head()
# Out:
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
# 4   5  373-73-7910      A     Yangon       Normal    Male
#
#               Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0       Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories      15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle      46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel      86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
d.Unitprice.min()
# Out:
# 10.08

# %%
d.Unitprice.mean()
# Out:
# 55.67212999999998

# %%
d.Quantity.max()
# Out:
# 10

# %%
d.Quantity.min()
# Out:
# 1

# %%
d.Quantity.mean()
# Out:
# 5.51

# %%
d.Quantity.count()
# Out:
# 1000

# %%
d.Unitprice.loc[d.Productline == "Health and beauty"].max()
# Out:
# 99.96

# %%
d.Unitprice.loc[d.Productline == "Health and beauty"].min()
# Out:
# 10.08

# %%
d.Unitprice.loc[d.Productline == "Health and beauty"].mean()
# Out:
# 54.85447368421053

# %%
d.groupby("Productline").mean()
# Out:
#                                 No  Unitprice  Quantity        Tax  \
# Productline
# Electronic accessories  515.758824  53.551588  5.711765  15.220597
# Fashion accessories     508.365169  57.153652  5.067416  14.528062
# Food and beverages      506.873563  56.008851  5.471264  15.365310
# Health and beauty       495.532895  54.854474  5.618421  15.411572
# Home and lifestyle      497.087500  55.316937  5.693750  16.030331
# Sports and travel       477.596386  56.993253  5.542169  15.812630
#
#                              Total        cogs  gross_margin_percentage  \
# Productline
# Electronic accessories  319.632538  304.411941                 4.761905
# Fashion accessories     305.089298  290.561236                 4.761905
# Food and beverages      322.671517  307.306207                 4.761905
# Health and beauty       323.643020  308.231447                 4.761905
# Home and lifestyle      336.636956  320.606625                 4.761905
# ...

# %%
# Out:
#              No    InvoiceID Branch Customertype Gender        Productline  \
# City
# Mandalay    997  895-66-0685      B       Normal   Male  Sports and travel
# Naypyitaw   996  894-41-5205      C       Normal   Male  Sports and travel
# Yangon     1000  898-04-2717      A       Normal   Male  Sports and travel
#
#            Unitprice  Quantity    Tax    Total      Date   Time  Payment  \
# City
# Mandalay       99.96        10  48.69  1022.49  3/9/2019  20:57  Ewallet
# Naypyitaw      99.96        10  49.65  1042.65  3/9/2019  20:59  Ewallet
# Yangon         99.83        10  49.49  1039.29  3/9/2019  20:59  Ewallet
#
#             cogs  gross_margin_percentage  gross_iincome  Rating
# City
# Mandalay   973.8                 4.761905          48.69    10.0
# Naypyitaw  993.0                 4.761905          49.65    10.0
# Yangon     989.8                 4.761905          49.49    10.0

# %%
d.Quantity.loc[d.Productline == "Electronic accessories"].mean()
# Out:
# 5.711764705882353

# %%
d.Quantity.loc[d.Productline == "Electronic accessories"].max()
# Out:
# 10

# %%
d.Quantity.loc[d.Productline == "Electronic accessories"].min()
# Out:
# 1

# %%
d.loc[(d['Productline'] == "Health and beauty") & (d['Gender'] == "Male") ]
# Out:
#       No    InvoiceID Branch       City Customertype Gender  \
# 3      4  123-19-1176      A     Yangon       Member   Male
# 21    22  371-85-5789      B   Mandalay       Normal   Male
# 29    30  848-62-7243      A     Yangon       Normal   Male
# 33    34  595-11-5460      A     Yangon       Normal   Male
# 44    45  617-15-4209      C  Naypyitaw       Member   Male
# ..   ...          ...    ...        ...          ...    ...
# 981  982  809-46-1866      A     Yangon       Normal   Male
# 983  984  148-41-7930      C  Naypyitaw       Normal   Male
# 987  988  552-44-5977      B   Mandalay       Member   Male
# 989  990  430-53-4718      B   Mandalay       Member   Male
# 995  996  233-67-5758      C  Naypyitaw       Normal   Male
#
#            Productline  Unitprice  Quantity      Tax     Total       Date  \
# 3    Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 21   Health and beauty      87.98         3  13.1970  277.1370   3/5/2019
# ...

# %%
d.loc[(d['Productline'] == "Fashion accessories") & (d['Gender'] == "Female") ]
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 10     11  351-62-0822      B   Mandalay       Member  Female
# 27     28  189-17-4241      A     Yangon       Normal  Female
# 49     50  574-22-5561      C  Naypyitaw       Member  Female
# 52     53  616-24-2851      B   Mandalay       Member  Female
# 67     68  109-28-2512      B   Mandalay       Member  Female
# ..    ...          ...    ...        ...          ...     ...
# 931   932  756-93-1854      C  Naypyitaw       Member  Female
# 955   956  846-10-0341      A     Yangon       Normal  Female
# 962   963  593-08-5916      A     Yangon       Normal  Female
# 985   986  374-38-5555      B   Mandalay       Normal  Female
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax     Total       Date  \
# 10   Fashion accessories      14.48         4   2.8960   60.8160   2/6/2019
# ...

# %%
d.loc[(d['Productline'] == "Fashion accessories") & (d['Productline'] =="Sports and travel") & (d['Gender'] == "Female") ].count()
# Out:
# No                         0
# InvoiceID                  0
# Branch                     0
# City                       0
# Customertype               0
# Gender                     0
# Productline                0
# Unitprice                  0
# Quantity                   0
# Tax                        0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross_margin_percentage    0
# gross_iincome              0
# Rating                     0
# dtype: int64

# %%
x=d.Tax.loc[d.Gender == "Male"]

x
# Out:
# 2      16.2155
# 3      23.2880
# 4      30.2085
# 5      29.8865
# 11      5.1020
#         ...
# 992     5.8030
# 993     8.7450
# 995     2.0175
# 997     1.5920
# 998     3.2910
# Name: Tax, Length: 499, dtype: float64

# %%
y=d.Quantity.loc[d.Gender == "Male"]
y
# Out:
# 2       7
# 3       8
# 4       7
# 5       7
# 11      4
#        ..
# 992     2
# 993    10
# 995     1
# 997     1
# 998     1
# Name: Quantity, Length: 499, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %%
d.Tax.loc[d.City == "Yangon"].sum()
# Out:
# 5057.1605

# %%
d.head()
# Out:
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
# 4   5  373-73-7910      A     Yangon       Normal    Male
#
#               Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0       Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories      15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle      46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel      86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
d.Quantity.loc[d.City == "Yangon"].sum()
# Out:
# 1859

# %%
d.Quantity.loc[d.City == "Mandalay"].sum()
# Out:
# 1820

# %%
d["Quantity"].loc[(d['City'] == "Yangon") & (d['Branch'] == "A") ]
# Out:
# 0      7
# 2      7
# 3      8
# 4      7
# 6      6
#       ..
# 990    5
# 992    2
# 997    1
# 998    1
# 999    7
# Name: Quantity, Length: 340, dtype: int64

# %%
d["Quantity"].loc[(d['City'] == "Yangon") & (d['Branch'] == "B") ]
# Out:
# Series([], Name: Quantity, dtype: int64)

# %%
d["Quantity"].loc[(d['City'] == "Yangon") & (d['Branch'] == "C") ]
# Out:
# Series([], Name: Quantity, dtype: int64)

# %%
x=d.Tax
x
# Out:
# 0      26.1415
# 1       3.8200
# 2      16.2155
# 3      23.2880
# 4      30.2085
#         ...
# 995     2.0175
# 996    48.6900
# 997     1.5920
# 998     3.2910
# 999    30.9190
# Name: Tax, Length: 1000, dtype: float64

# %%
y=d.Unitprice
y
# Out:
# 0      74.69
# 1      15.28
# 2      46.33
# 3      58.22
# 4      86.31
#        ...
# 995    40.35
# 996    97.38
# 997    31.84
# 998    65.82
# 999    88.34
# Name: Unitprice, Length: 1000, dtype: float64

# %%
plt.scatter(x,y)

# %%
d.gross_iincome.max()
# Out:
# 49.65

# %%
for x in d.index:
    if d.gross_iincome[x]==49.65:
        print(d.Branch[x]) 
        print(d.InvoiceID[x])
# Out:
# C
# 860-79-0874

# %%
for x in d.index:
    if d.gross_iincome[x]==49.65:
        print(d.Gender[x])
# Out:
# Female

# %%
for x in d.index:
    if d.gross_iincome[x]==49.65:
        print(d.Customertype[x])
# Out:
# Member

# %%
d.gross_iincome.min()
# Out:
# 0.5085

# %%
for x in d.index:
    if d.gross_iincome[x] == 0.5085:
        print(d.InvoiceID[x])
# Out:
# 784-21-9238

# %%
d.groupby("gross_iincome").min()
# Out:
#                 No    InvoiceID Branch       City Customertype  Gender  \
# gross_iincome
# 0.5085         823  784-21-9238      C  Naypyitaw       Member    Male
# 0.6045         630  308-39-1707      A     Yangon       Normal  Female
# 0.6270         224  279-62-1445      C  Naypyitaw       Member  Female
# 0.6390         444  192-98-7397      C  Naypyitaw       Normal    Male
# 0.6990         403  236-86-3015      C  Naypyitaw       Member    Male
# ...            ...          ...    ...        ...          ...     ...
# 48.6900        997  303-96-2227      B   Mandalay       Normal  Female
# 48.7500        700  751-41-9720      C  Naypyitaw       Normal    Male
# 49.2600        558  283-26-5248      C  Naypyitaw       Member  Female
# 49.4900        168  687-47-8271      A     Yangon       Normal    Male
# 49.6500        351  860-79-0874      C  Naypyitaw       Member  Female
#
#                        Productline  Unitprice  Quantity      Tax      Total  \
# gross_iincome
# ...

# %%
x=d.Payment
x
# Out:
# 0          Ewallet
# 1             Cash
# 2      Credit card
# 3          Ewallet
# 4          Ewallet
#           ...
# 995        Ewallet
# 996        Ewallet
# 997           Cash
# 998           Cash
# 999           Cash
# Name: Payment, Length: 1000, dtype: object

# %%
y=d.gross_iincome
y
# Out:
# 0      26.1415
# 1       3.8200
# 2      16.2155
# 3      23.2880
# 4      30.2085
#         ...
# 995     2.0175
# 996    48.6900
# 997     1.5920
# 998     3.2910
# 999    30.9190
# Name: gross_iincome, Length: 1000, dtype: float64

# %%
plt.scatter(x,y)

# %%
d.groupby("Rating").max()
# Out:
#          No    InvoiceID Branch    City Customertype Gender  \
# Rating
# 4.0     877  885-56-0389      C  Yangon       Normal   Male
# 4.1     999  871-39-9221      C  Yangon       Normal   Male
# 4.2     945  895-03-6665      C  Yangon       Normal   Male
# 4.3     989  826-58-8051      C  Yangon       Normal   Male
# 4.4     997  870-76-1733      C  Yangon       Normal   Male
# ...     ...          ...    ...     ...          ...    ...
# 9.6     872  875-31-8302      C  Yangon       Normal   Male
# 9.7     847  746-68-6593      C  Yangon       Normal   Male
# 9.8     981  805-86-0265      C  Yangon       Normal   Male
# 9.9     883  868-52-7573      C  Yangon       Normal   Male
# 10.0    854  866-70-2814      C  Yangon       Normal   Male
#
#               Productline  Unitprice  Quantity      Tax      Total       Date  \
# Rating
# 4.0     Sports and travel      98.53         9  32.7960   688.7160   3/5/2019
# ...

# %%
y=d.Unitprice

# %%
x=d.Rating

# %%
plt.scatter(x,y)

# %%
d.Rating.max()
# Out:
# 10.0

# %%
for x in d.index:
    if d.Rating[x]==10.0:
        print(d.Branch[x])
        print(d.City[x])
# Out:
# C
# Naypyitaw
# B
# Mandalay
# B
# Mandalay
# A
# Yangon
# B
# Mandalay

# %%
for x in d.index:
    if d.Rating[x]==10.0:
        print(d.Gender[x])
# Out:
# Female
# Female
# Male
# Female
# Female
